# %% [markdown]
# # Keras로 Linear&Logistic Regression 조금 더 맛보기

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import pandas as pd

# %% [markdown]
# # Linear Regression on 쬐금 더 어려운 데이터

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
x = boston.data
y = boston.target

x.shape, y.shape
# Out:
# ((506, 13), (506,))

# %%
keras.backend.clear_session()

model = keras.models.Sequential()

model.add( keras.layers.Input(shape=(13,)))
model.add( keras.layers.Dense(1)) # activation default = 'linear'

model.compile(loss='mse', optimizer='adam')

# %%
model.fit(x, y, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 2ms/step - loss: 89994.3516
# Epoch 2/10
# 16/16 [==============================] - 0s 2ms/step - loss: 81487.9141
# Epoch 3/10
# 16/16 [==============================] - 0s 2ms/step - loss: 73466.2969
# Epoch 4/10
# 16/16 [==============================] - 0s 2ms/step - loss: 66033.3516
# Epoch 5/10
# 16/16 [==============================] - 0s 2ms/step - loss: 59248.3047
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 52954.8555
# Epoch 7/10
# 16/16 [==============================] - 0s 2ms/step - loss: 47192.7773
# Epoch 8/10
# 16/16 [==============================] - 0s 2ms/step - loss: 41957.6797
# Epoch 9/10
# 16/16 [==============================] - 0s 2ms/step - loss: 37171.1562
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 32866.0586

# %%
model.predict(x)[:5].reshape(-1)
# Out:
# array([-142.95715, -124.0558 , -130.21925, -132.5078 , -129.54214],
#       dtype=float32)

# %%
y[:5].reshape(-1)
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2])

# %% [markdown]
# # Logistic Regression 쬐금 더 어려운 데이터

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()

# %%
x = cancer.data
y = cancer.target

# 모양 확인해볼 것
x.shape, y.shape
# Out:
# ((569, 30), (569,))

# %%
from tensorflow.python import metrics
keras.backend.clear_session()

model = keras.models.Sequential()

model.add( keras.layers.Input(shape=(30,)))
model.add( keras.layers.Dense(1, activation='sigmoid'))

#model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.compile(loss=keras.losses.BinaryCrossentropy(), optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x, y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2697 - accuracy: 0.9069
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2680 - accuracy: 0.9069
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2642 - accuracy: 0.8981
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2814 - accuracy: 0.9086
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2568 - accuracy: 0.9016
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2683 - accuracy: 0.8981
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2584 - accuracy: 0.9016
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2478 - accuracy: 0.9104
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.2524 - accuracy: 0.9086
# Epoch 10/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2459 - accuracy: 0.9086
# Epoch 11/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2445 - accuracy: 0.9086
# Epoch 12/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2456 - accuracy: 0.9104
# Epoch 13/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2378 - accuracy: 0.9104
# Epoch 14/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2482 - accuracy: 0.9104
# Epoch 15/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2408 - accuracy: 0.9051
# Epoch 16/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2372 - accuracy: 0.9104
# Epoch 17/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2243 - accuracy: 0.9086
# Epoch 18/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2304 - accuracy: 0.8928
# Epoch 19/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2221 - accuracy: 0.8963
# Epoch 20/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2188 - accuracy: 0.9086
# Epoch 21/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2182 - accuracy: 0.9104
# Epoch 22/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.