# %% [markdown]
# # My First Convolutional Neural Network
#
# ## CIFAR-10
#
# #### 실습목표<br>
# 1. CNN의 기본 아이디어를 안다.
# 2. CNN의 구조를 그리고, 코드로 옮길 수 있다.

# %% [markdown]
# ## Real Game : CNN on CIFAR-10
#
# 여기에서는 여러분이 직접 코드를 완성해야 하는 문제가 곳곳에 있습니다!

# %%
'''
matplolib inline 명령어를 통해서
matplot으로 그리는 플롯들을 주피터 노트북 내에서 볼 수 있게 해준다.
포맷을 retina로 바꾸면 그래프의 화질이 훨씬 좋아진다.
'''
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

'''
라이브러리들을 불러오자.
'''
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras


from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Input, Dense, Flatten, BatchNormalization, Activation, Dropout, Conv2D, MaxPool2D
from tensorflow.keras import layers, models
from tensorflow.keras import backend

import random as rd

from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Data Loading

# %%
(train_x, train_y), (test_x, test_y) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 13s 0us/step
# 170508288/170498071 [==============================] - 13s 0us/step

# %%
print(train_x.shape, train_y.shape, test_x.shape, test_y.shape)
# Out:
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %%
labels = { 0 : 'Airplane',
          1 : 'Automobile',
          2 : 'Bird',
          3 : 'Cat',
          4 : 'Deer',
          5 : 'Dog',
          6 : 'Frog',
          7 : 'Horse',
          8 : 'Ship',
          9 : 'Truck' }

print(labels)
# Out:
# {0: 'Airplane', 1: 'Automobile', 2: 'Bird', 3: 'Cat', 4: 'Deer', 5: 'Dog', 6: 'Frog', 7: 'Horse', 8: 'Ship', 9: 'Truck'}

# %%
'''
Ctrl+Enter를 이용하여
반복 실행 해보자!
'''

id = rd.randrange(0,10000)

print(f'id = {id}')
print(f'다음 그림은 {labels[test_y[id][0]]} 입니다.')
plt.imshow(test_x[id])
plt.show()
# Out:
# id = 9002
# 다음 그림은 Frog 입니다.

# %% [markdown]
# ### X : 표준화 Scaling (standardization)
#
# $$ X_{scaled} = {{x_{original} - mean(x)}\over{std(x)} } $$

# %%
x_mean, x_std = train_x.mean(), train_x.std()
x_mean, x_std
# Out:
# (120.70756512369792, 64.1500758911213)

# %%
train_x = (train_x - x_mean) / x_std
test_x = (test_x - x_mean) / x_std

# %%
train_x.mean(), train_x.std()
# Out:
# (-2.5247951877342226e-17, 1.0000000000000022)

# %% [markdown]
# ### Y : One-Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

# %%
n = len(np.unique(train_y))
n
# Out:
# 10

# %%
train_y = to_categorical(train_y, n)
test_y = to_categorical(test_y, n)

# %%
train_y.shape, test_y.shape
# Out:
# ((50000, 10), (10000, 10))

# %% [markdown]
# ### 코드를 완성해주세요!
#
# #### **model.fit( ) 을 history 에 담아서 학습 과정의 로그를 남길 것.**
#
# **자유롭게 먼저 해보는 것을 추천**
#
# **구조를 따라서 코딩을 한다면..**
#
# 0. Functional, Sequential 중 택일
# 1. 인풋레이어
# 1. Convolution : 필터수 32개, 사이즈(3, 3), same padding
# 2. Convolution : 필터수 32개, 사이즈(3, 3), same padding
# 3. BatchNormalization
# 4. MaxPooling : 사이즈(2,2) 스트라이드(2,2)
# 5. DropOut : 25% 비활성화
# 1. Convolution : 필터수 64개, 사이즈(3, 3), same padding
# 2. Convolution : 필터수 64개, 사이즈(3, 3), same padding
# 3. BatchNormalization
# 4. MaxPooling : 사이즈(2,2) 스트라이드(2,2)
# 5. DropOut : 25% 비활성화
# 6. Flatten( )
# 7. Fully Connected Layer : 노드 1024개
# 3. BatchNormalization
# 5. DropOut : 35% 비활성화
# 9. 아웃풋레이어
#
# * EarlyStopping 의 옵션도 조절해보자.

# %%
train_x.shape, test_x.shape, train_y.shape, test_y.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 10), (10000, 10))

# %%
from tensorflow.python import metrics
backend.clear_session()

# Functional, Sequential 중 택일
# 인풋레이어
il = Input(shape=(32,32,3))

# Convolution : 필터수 32개, 사이즈(3, 3), same padding
cl = Conv2D(filters=32,
            kernel_size=(3,3),
            strides=(1,1),
            padding='same',
            activation='swish')(il)

# Convolution : 필터수 32개, 사이즈(3, 3), same padding
cl = Conv2D(filters=32,
            kernel_size=(3,3),
            strides=(1,1),
            padding='same',
            activation='swish')(cl)

# BatchNormalization
bl = BatchNormalization()(cl)

# MaxPooling : 사이즈(2,2) 스트라이드(2,2)
ml = MaxPool2D(pool_size=(2,2), strides=(2,2))(bl)

# DropOut : 25% 비활성화
dl = Dropout(rate=0.25)(ml)

# Convolution : 필터수 64개, 사이즈(3, 3), same padding
cl = Conv2D(filters=64,
            kernel_size=(3,3),
            strides=(1,1),
            padding='same',
            activation='swish')(dl)

# Convolution : 필터수 64개, 사이즈(3, 3), same padding
cl = Conv2D(filters=64,
            kernel_size=(3,3),
            strides=(1,1),
            padding='same',
            activation='swish')(cl)

# BatchNormalization
bl = BatchNormalization()(cl)

# MaxPooling : 사이즈(2,2) 스트라이드(2,2)
ml = MaxPool2D(pool_size=(2,2), strides=(2,2))(bl)

# DropOut : 25% 비활성화
dl = Dropout(rate=0.25)(ml)

# Flatten( )
fl = Flatten()(dl)

# Fully Connected Layer : 노드 1024개
hl = Dense(1024, activation='swish')(fl)

# BatchNormalization
bl = BatchNormalization()(hl)

# DropOut : 35% 비활성화
dl = Dropout(rate=0.35)(bl)

# 아웃풋레이어
ol = Dense(10, activation='softmax')(dl)

model = models.Model(il, ol)

model.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 1024)              4195328
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 4,275,626
# Trainable params: 4,273,386
# Non-trainable params: 2,240
# _________________________________________________________________

# %% [markdown]
# #### 모델 학습

# %%
es = EarlyStopping(monitor='val_loss',
                   min_delta=0,
                   patience=5,
                   verbose=1,
                   restore_best_weights=True)

# %%
history = model.fit(train_x,
                    train_y, batch_size=64, epochs=1, verbose=1,
                    callbacks=[es], validation_split=0.1)
# Out:
# 625/625 [==============================] - 8s 13ms/step - loss: 1.1146 - accuracy: 0.6162 - val_loss: 1.3309 - val_accuracy: 0.5637

# %%
history = model.fit(train_x,
                    train_y, batch_size=128, epochs=1, verbose=1,
                    callbacks=[es], validation_split=0.1)
# Out:
# 313/313 [==============================] - 8s 21ms/step - loss: 1.6079 - accuracy: 0.4780 - val_loss: 3.2364 - val_accuracy: 0.1231

# %%
history = model.fit(train_x,
                    train_y, batch_size=256, epochs=1, verbose=1,
                    callbacks=[es], validation_split=0.1)
# Out:
# 157/157 [==============================] - 7s 38ms/step - loss: 1.6634 - accuracy: 0.4674 - val_loss: 3.5140 - val_accuracy: 0.0997

# %%
history = model.fit(train_x,
                    train_y, batch_size=512, epochs=1, verbose=1,
                    callbacks=[es], validation_split=0.1)
# Out:
# 79/79 [==============================] - 5s 65ms/step - loss: 1.0948 - accuracy: 0.6218 - val_loss: 4.5077 - val_accuracy: 0.1107

# %%
history = model.fit(train_x,
                    train_y, batch_size=1024, epochs=1, verbose=1,
                    callbacks=[es], validation_split=0.1)
# Out:
# 40/40 [==============================] - 5s 121ms/step - loss: 1.2160 - accuracy: 0.5806 - val_loss: 3.2138 - val_accuracy: 0.1016

# %%
history = model.fit(train_x,
                    train_y, batch_size=2048, epochs=1, verbose=1,
                    callbacks=[es], validation_split=0.1)
# Out:
# 20/20 [==============================] - 9s 352ms/step - loss: 1.4108 - accuracy: 0.5209 - val_loss: 2.6800 - val_accuracy: 0.1008

# %%
history = model.fit(train_x,
                    train_y, batch_size=1024, epochs=1000, verbose=1,
                    callbacks=[es], validation_split=0.1)
# Out:
# Epoch 1/1000
# 44/44 [==============================] - 20s 153ms/step - loss: 1.9041 - accuracy: 0.4291 - val_loss: 2.5075 - val_accuracy: 0.1180
# Epoch 2/1000
# 44/44 [==============================] - 5s 110ms/step - loss: 1.2167 - accuracy: 0.5823 - val_loss: 2.9019 - val_accuracy: 0.1370
# Epoch 3/1000
# 44/44 [==============================] - 5s 111ms/step - loss: 0.9936 - accuracy: 0.6521 - val_loss: 3.2305 - val_accuracy: 0.1554
# Epoch 4/1000
# 44/44 [==============================] - 5s 111ms/step - loss: 0.8622 - accuracy: 0.6999 - val_loss: 3.1100 - val_accuracy: 0.2194
# Epoch 5/1000
# 44/44 [==============================] - 5s 111ms/step - loss: 0.7417 - accuracy: 0.7387 - val_loss: 2.8003 - val_accuracy: 0.2496
# Epoch 6/1000
# 44/44 [==============================] - 5s 112ms/step - loss: 0.6371 - accuracy: 0.7777 - val_loss: 2.2234 - val_accuracy: 0.3210
# Epoch 7/1000
# 44/44 [==============================] - 5s 111ms/step - loss: 0.5495 - accuracy: 0.8097 - val_loss: 1.8240 - val_accuracy: 0.4078
# Epoch 8/1000
# 44/44 [==============================] - 5s 112ms/step - loss: 0.4804 - accuracy: 0.8325 - val_loss: 1.3664 - val_accuracy: 0.5252
# Epoch 9/1000
# 44/44 [==============================] - 5s 112ms/step - loss: 0.4104 - accuracy: 0.8586 - val_loss: 1.2034 - val_accuracy: 0.6016
# Epoch 10/1000
# 44/44 [==============================] - 5s 112ms/step - loss: 0.3476 - accuracy: 0.8821 - val_loss: 1.0218 - val_accuracy: 0.6600
# Epoch 11/1000
# 44/44 [==============================] - 5s 112ms/step - loss: 0.2923 - accuracy: 0.9004 - val_loss: 0.8733 - val_accuracy: 0.7086
# Epoch 12/1000
# 44/44 [==============================] - 5s 113ms/step - loss: 0.2538 - accuracy: 0.9156 - val_loss: 0.8379 - val_accuracy: 0.7284
# Epoch 13/1000
# 44/44 [==============================] - 5s 113ms/step - loss: 0.2177 - accuracy: 0.9282 - val_loss: 0.8168 - val_accuracy: 0.7390
# Epoch 14/1000
# 44/44 [==============================] - 5s 113ms/step - loss: 0.1897 - accuracy: 0.9372 - val_loss: 0.7149 - val_accuracy: 0.7754
# Epoch 15/1000
# 44/44 [==============================] - 5s 113ms/step - loss: 0.1641 - accuracy: 0.9472 - val_loss: 0.7153 - val_accuracy: 0.7800
# Epoch 16/1000
# 44/44 [==============================] - 5s 113ms/step - loss: 0.1476 - accuracy: 0.9527 - val_loss: 0.7381 - val_accuracy: 0.7726
# Epoch 17/1000
# 44/44 [==============================] - 5s 114ms/step - loss: 0.1351 - accuracy: 0.9562 - val_loss: 0.7056 - val_accuracy: 0.7814
# Epoch 18/1000
# 44/44 [==============================] - 5s 113ms/step - loss: 0.1204 - accuracy: 0.9616 - val_loss: 0.7505 - val_accuracy: 0.7758
# Epoch 19/1000
# 44/44 [==============================] - 5s 114ms/step - loss: 0.1121 - accuracy: 0.9646 - val_loss: 0.7556 - val_accuracy: 0.7868
# Epoch 20/1000
# 44/44 [==============================] - 5s 113ms/step - loss: 0.1026 - accuracy: 0.9668 - val_loss: 0.7227 - val_accuracy: 0.7912
# Epoch 21/1000
# 44/44 [==============================] - 5s 114ms/step - loss: 0.0911 - accuracy: 0.9715 - val_loss: 0.7519 - val_accuracy: 0.7830
# Epoch 22/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.0876 - accuracy: 0.9721Restoring model weights from the end of the best epoch: 17.
# 44/44 [==============================] - 5s 115ms/step - loss: 0.0876 - accuracy: 0.9721 - val_loss: 0.7708 - val_accuracy: 0.7886
# Epoch 22: early stopping

# %% [markdown]
# ### 성능 평가

# %%
performance_test = model.evaluate(test_x, test_y, batch_size=100)

print('Test Loss : {:.6f},  Test Accuracy : {:.3f}%'.format(performance_test[0], performance_test[1]*100))
# Out:
# 100/100 [==============================] - 1s 7ms/step - loss: 0.7484 - accuracy: 0.7714
# Test Loss : 0.748415,  Test Accuracy : 77.140%

# %%
if not isinstance(history, dict):
    history = history.history

plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('Accuracy : Training vs Validation')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc=0)
plt.show()

# %%
if not isinstance(history, dict):
    history = history.history

plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Loss : Training vs Validation')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc=0)
plt.show()

# %%
# 원핫인코딩 해제
train_y = train_y.argmax(axis=1)
test_y = test_y.argmax(axis=1)

# %%
pred_train = model.predict(train_x)
pred_test = model.predict(test_x)

single_pred_train = pred_train.argmax(axis=1)
single_pred_test = pred_test.argmax(axis=1)

logi_train_accuracy = accuracy_score(train_y, single_pred_train)
logi_test_accuracy = accuracy_score(test_y, single_pred_test)

print('CNN')
print(f'트레이닝 정확도 : {logi_train_accuracy*100:.2f}%')
print(f'테스트 정확도 : {logi_test_accuracy*100:.2f}%')
# Out:
# CNN
# 트레이닝 정확도 : 97.49%
# 테스트 정확도 : 77.14%

# %%
'''
성능 확인을 위해
Ctrl+Enter를 이용하여
반복 실행 해보자!
'''

id = rd.randrange(0,10000)

print(f'id = {id}')
print(f'다음 그림은 {labels[test_y[id]]} 입니다.')
print(f'모델의 예측 : {labels[single_pred_test[id]]}')

prob = np.floor(pred_test[id]*100).tolist()
prob_dict = {}

for idx, prob in enumerate(prob) :
    prob_dict[ labels[idx] ] = prob

print('모델의 카테고리별 확률 : ')
print(prob_dict)

if test_y[id] == single_pred_test[id] :
    print('정답입니다')
else : 
    print('틀렸어요')
    
plt.imshow(test_x[id].reshape([32,32,-1]))
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# id = 6881
# 다음 그림은 Bird 입니다.
# 모델의 예측 : Deer
# 모델의 카테고리별 확률 :
# {'Airplane': 26.0, 'Automobile': 1.0, 'Bird': 19.0, 'Cat': 11.0, 'Deer': 34.0, 'Dog': 5.0, 'Frog': 1.0, 'Horse': 0.0, 'Ship': 0.0, 'Truck': 0.0}
# 틀렸어요

# %%
'''
틀린 것만 관찰해보자!

Ctrl+Enter를 이용하여
반복 실행 해보자!
'''

true_false = (test_y == single_pred_test)
f_id = np.where(true_false == False)[0]
f_n = len(f_id)

id = f_id[rd.randrange(0,f_n)]


print(f'id = {id}')
print(f'다음 그림은 {labels[test_y[id]]} 입니다.')
print(f'모델의 예측 : {labels[single_pred_test[id]]}')

prob = np.floor(pred_test[id]*100).tolist()
prob_dict = {}

for idx, prob in enumerate(prob) :
    prob_dict[ labels[idx] ] = prob

print('모델의 카테고리별 확률 : ')
print(prob_dict)

if test_y[id] == single_pred_test[id] :
    print('정답입니다')
else : 
    print('틀렸어요')
    
plt.imshow(test_x[id].reshape([32,32,-1]))
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# id = 1355
# 다음 그림은 Dog 입니다.
# 모델의 예측 : Cat
# 모델의 카테고리별 확률 :
# {'Airplane': 2.0, 'Automobile': 1.0, 'Bird': 30.0, 'Cat': 37.0, 'Deer': 0.0, 'Dog': 22.0, 'Frog': 1.0, 'Horse': 0.0, 'Ship': 0.0, 'Truck': 4.0}
# 틀렸어요
